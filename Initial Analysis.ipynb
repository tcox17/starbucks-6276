# %% [markdown]
# # Exploratory Analysis for Starbucks Data and Preprocessing

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Original Datasources (Do Not Modify)',
#  'portfolio.csv',
#  'profile.csv',
#  'transcript.csv',
#  'Untitled.ipynb']

# %% [markdown]
# Please verify that you've unzipped the file archive & that portfolio.csv, profile.csv, and transcript.csv are all present in your current directory.

# %% [markdown]
# ## Loading data

# %%
import pandas as pd

# %%
port = pd.read_csv('portfolio.csv', index_col = 0) # index col = 0 since the index is unnamed in the csvs
prof = pd.read_csv('profile.csv', index_col = 0)
tran = pd.read_csv('transcript.csv', index_col = 0)

# %% [markdown]
# ## Examining and Preprocessing Data

# %% [markdown]
# ### Profile Data

# %%
prof.head()
# Out:
#   gender  age                                id  became_member_on    income
# 0    NaN  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1      F   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2    NaN  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3      F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4    NaN  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN

# %%
prof.isna().sum() # Looks like we are missing the same amount of gender / income.
# Out:
# gender              2175
# age                    0
# id                     0
# became_member_on       0
# income              2175
# dtype: int64

# %%
(prof['age'] == 118).value_counts()
# Out:
# False    14825
# True      2175
# Name: age, dtype: int64

# %%
print('Missing data makes up about {}% of total profile rows'.format(round(2175/(14825+2175), 3) * 100))
# Out:
# Missing data makes up about 12.8% of total profile rows

# %% [markdown]
# So, all of the missing values occur on the same rows - where one column is missing data, so are the others (gender, age, income). For now, lets just drop them.

# %%
prof.dropna(inplace = True)

# %%
prof.isna().any() # Verify there are no missing values in prof
# Out:
# gender              False
# age                 False
# id                  False
# became_member_on    False
# income              False
# dtype: bool

# %% [markdown]
# ### Transcript Data

# %%
tran.isna().sum() # No missing values for tran file!
# Out:
# person    0
# event     0
# value     0
# time      0
# dtype: int64

# %%
tran.head()
# Out:
#                              person           event  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received
# 1  a03223e636434f42ac4c3df47e8bac43  offer received
# 2  e2127556f4f64592b11af22de27a7932  offer received
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  offer received
# 4  68617ca6246f4fbc85e91a2a49552598  offer received
#
#                                               value  time
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0
# 2  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}     0
# 3  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}     0
# 4  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0

# %%
tran['value'].value_counts()
# Out:
# {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}    14983
# {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}    14924
# {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}    14891
# {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}    14835
# {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}    14374
#                                                     ...
# {'amount': 54.99}                                       1
# {'amount': 49.94}                                       1
# {'amount': 65.33}                                       1
# {'amount': 508.19}                                      1
# {'amount': 40.89}                                       1
# Name: value, Length: 5121, dtype: int64

# %%
tran[tran['event'] == 'transaction']
# Out:
#                                   person        event  \
# 12654   02c083884c7d45b39cc68e1314fec56c  transaction
# 12657   9fa9ae8f57894cc9a3b8a9bbe0fc1b2f  transaction
# 12659   54890f68699049c2a04d415abc25e717  transaction
# 12670   b2f1cd155b864803ad8334cdf13c4bd2  transaction
# 12671   fe97aa22dd3e48c8b143116a8403dd52  transaction
# ...                                  ...          ...
# 306529  b3a1272bc9904337b331bf348c3e8c17  transaction
# 306530  68213b08d99a4ae1b0dcb72aebd9aa35  transaction
# 306531  a00058cf10334a308c68e7631c529907  transaction
# 306532  76ddbd6576844afe811f1a3c0fbb5bec  transaction
# 306533  c02b10e8752c4d8e9b73f918558531f7  transaction
#
#                                  value  time
# 12654   {'amount': 0.8300000000000001}     0
# 12657                {'amount': 34.56}     0
# 12659                {'amount': 13.23}     0
# 12670                {'amount': 19.51}     0
# 12671                {'amount': 18.97}     0
# ...                                ...   ...
# 306529  {'amount': 1.5899999999999999}   714
# 306530                {'amount': 9.53}   714
# 306531                {'amount': 3.61}   714
# 306532  {'amount': 3.5300000000000002}   714
# 306533                {'amount': 4.05}   714
#
# [138953 rows x 4 columns]

# %%
tran['event'].value_counts()
# Out:
# transaction        138953
# offer received      76277
# offer viewed        57725
# offer completed     33579
# Name: event, dtype: int64

# %%
def parse_value():
    pass

# %%
import ast

# %%
tran['offer_id'] = None
tran['amount'] = None

for i in tran.iterrows():
    if i[1]['event'] == 'offer received':
        tran.at[i[0], 'offer_id'] = ast.literal_eval(i[1]['value'])['offer id']
    elif i[1]['event'] == 'offer viewed':
        tran.at[i[0], 'offer_id'] = ast.literal_eval(i[1]['value'])['offer id']
    elif i[1]['event'] == 'offer completed':
        pass
    elif i[1]['event'] == 'transaction':
        tran.at[i[0], 'amount'] = ast.literal_eval(i[1]['value'])['amount']

# %%
tran['person'].value_counts()
# Out:
# 94de646f7b6041228ca7dec82adb97d2    51
# 8dbfa485249f409aa223a2130f40634a    49
# 5e60c6aa3b834e44b822ea43a3efea26    48
# d0a80415b84c4df4908b8403b19765e3    48
# 79d9d4f86aca4bed9290350fb43817c2    48
#                                     ..
# 3a4e53046c544134bb1e7782248631d1     2
# e63e42480aae4ede9f07cac49c8c3f78     2
# 912b9f623b9e4b4eb99b6dc919f09a93     2
# fccc9279ba56411f80ffe8ce7e0935cd     2
# da7a7c0dcfcb41a8acc7864a53cf60fb     1
# Name: person, Length: 17000, dtype: int64

# %%
tran[tran['person'] == '94de646f7b6041228ca7dec82adb97d2']
# Out:
#                                   person            event  \
# 2276    94de646f7b6041228ca7dec82adb97d2   offer received
# 16010   94de646f7b6041228ca7dec82adb97d2     offer viewed
# 24531   94de646f7b6041228ca7dec82adb97d2      transaction
# 24532   94de646f7b6041228ca7dec82adb97d2  offer completed
# 42252   94de646f7b6041228ca7dec82adb97d2      transaction
# 55475   94de646f7b6041228ca7dec82adb97d2   offer received
# 75256   94de646f7b6041228ca7dec82adb97d2     offer viewed
# 77624   94de646f7b6041228ca7dec82adb97d2      transaction
# 81725   94de646f7b6041228ca7dec82adb97d2      transaction
# 93913   94de646f7b6041228ca7dec82adb97d2      transaction
# 96627   94de646f7b6041228ca7dec82adb97d2      transaction
# 97913   94de646f7b6041228ca7dec82adb97d2      transaction
# 99190   94de646f7b6041228ca7dec82adb97d2      transaction
# 99191   94de646f7b6041228ca7dec82adb97d2  offer completed
# 100437  94de646f7b6041228ca7dec82adb97d2      transaction
# 101667  94de646f7b6041228ca7dec82adb97d2      transaction
# 102890  94de646f7b6041228ca7dec82adb97d2      transaction
# 104013  94de646f7b6041228ca7dec82adb97d2      transaction
# 109101  94de646f7b6041228ca7dec82adb97d2      transaction
# 110041  94de646f7b6041228ca7dec82adb97d2      transaction
# 113102  94de646f7b6041228ca7dec82adb97d2   offer received
# 152891  94de646f7b6041228ca7dec82adb97d2   offer received
# 164148  94de646f7b6041228ca7dec82adb97d2     offer viewed
# 168269  94de646f7b6041228ca7dec82adb97d2      transaction
# 171735  94de646f7b6041228ca7dec82adb97d2      transaction
# 171736  94de646f7b6041228ca7dec82adb97d2  offer completed
# 177767  94de646f7b6041228ca7dec82adb97d2      transaction
# 180401  94de646f7b6041228ca7dec82adb97d2      transaction
# 185283  94de646f7b6041228ca7dec82adb97d2      transaction
# 187480  94de646f7b6041228ca7dec82adb97d2      transaction
# 193520  94de646f7b6041228ca7dec82adb97d2      transaction
# 198779  94de646f7b6041228ca7dec82adb97d2      transaction
# 198780  94de646f7b6041228ca7dec82adb97d2  offer completed
# 203846  94de646f7b6041228ca7dec82adb97d2   offer received
# 222483  94de646f7b6041228ca7dec82adb97d2     offer viewed
# 222484  94de646f7b6041228ca7dec82adb97d2      transaction
# 235588  94de646f7b6041228ca7dec82adb97d2      transaction
# 237713  94de646f7b6041228ca7dec82adb97d2      transaction
# 247375  94de646f7b6041228ca7dec82adb97d2   offer received
# 258696  94de646f7b6041228ca7dec82adb97d2      transaction
# 266174  94de646f7b6041228ca7dec82adb97d2      transaction
# 275001  94de646f7b6041228ca7dec82adb97d2      transaction
# 275002  94de646f7b6041228ca7dec82adb97d2  offer completed
# 282196  94de646f7b6041228ca7dec82adb97d2     offer viewed
# 282197  94de646f7b6041228ca7dec82adb97d2      transaction
# 293425  94de646f7b6041228ca7dec82adb97d2      transaction
# 295012  94de646f7b6041228ca7dec82adb97d2      transaction
# 298164  94de646f7b6041228ca7dec82adb97d2      transaction
# 300877  94de646f7b6041228ca7dec82adb97d2      transaction
# 302162  94de646f7b6041228ca7dec82adb97d2      transaction
# 303445  94de646f7b6041228ca7dec82adb97d2      transaction
#
#                                                     value  time  \
# 2276     {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}     0
# 16010    {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}     6
# 24531                                    {'amount': 7.41}    30
# 24532   {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d...    30
# 42252                                    {'amount': 1.47}   102
# 55475    {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}   168
# 75256    {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}   186
# 77624                                    {'amount': 2.62}   192
# 81725                                    {'amount': 0.59}   204
# 93913                      {'amount': 2.2800000000000002}   246
# 96627                                    {'amount': 1.56}   258
# 97913                                    {'amount': 2.74}   264
# 99190                                    {'amount': 6.98}   270
# 99191   {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...   270
# 100437                                   {'amount': 5.87}   276
# 101667                                   {'amount': 3.77}   282
# 102890                                   {'amount': 0.33}   288
# 104013                                    {'amount': 1.0}   294
# 109101                                   {'amount': 2.98}   324
# 110041                                   {'amount': 0.52}   330
# 113102   {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}   336
# 152891   {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}   408
# 164148   {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}   408
# 168269                                   {'amount': 9.66}   414
# 171735                                   {'amount': 1.35}   420
# 171736  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...   420
# 177767                     {'amount': 1.8399999999999999}   432
# 180401                                   {'amount': 0.93}   438
# 185283                                   {'amount': 2.79}   450
# 187480                     {'amount': 1.7000000000000002}   456
# 193520                                   {'amount': 0.99}   474
# 198779                                    {'amount': 1.4}   492
# 198780  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7...   492
# 203846   {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}   504
# 222483   {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}   516
# 222484                                   {'amount': 0.27}   516
# 235588                                   {'amount': 1.02}   546
# 237713                                    {'amount': 2.7}   552
# 247375   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}   576
# 258696                                   {'amount': 4.13}   576
# 266174                                   {'amount': 0.31}   588
# 275001                                   {'amount': 5.64}   606
# 275002  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...   606
# 282196   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}   624
# 282197                                   {'amount': 6.18}   624
# 293425                                   {'amount': 1.78}   660
# 295012                    {'amount': 0.41000000000000003}   666
# 298164                                   {'amount': 0.42}   678
# 300877                                   {'amount': 0.73}   690
# 302162                                   {'amount': 4.96}   696
# 303445                                    {'amount': 0.9}   702
#
#                                 offer_id amount
# 2276    f19421c1d4aa40978ebb69ca19b0e20d   None
# 16010   f19421c1d4aa40978ebb69ca19b0e20d   None
# 24531                               None   7.41
# 24532                               None   None
# 42252                               None   1.47
# 55475   9b98b8c7a33c4b65b9aebfe6a799e6d9   None
# 75256   9b98b8c7a33c4b65b9aebfe6a799e6d9   None
# 77624                               None   2.62
# 81725                               None   0.59
# 93913                               None   2.28
# 96627                               None   1.56
# 97913                               None   2.74
# 99190                               None   6.98
# 99191                               None   None
# 100437                              None   5.87
# 101667                              None   3.77
# 102890                              None   0.33
# 104013                              None    1.0
# 109101                              None   2.98
# 110041                              None   0.52
# 113102  0b1e1539f2cc45b7b9fa7c272da2e1d7   None
# 152891  fafdcd668e3743c1bb461111dcafc2a4   None
# 164148  fafdcd668e3743c1bb461111dcafc2a4   None
# 168269                              None   9.66
# 171735                              None   1.35
# 171736                              None   None
# 177767                              None   1.84
# 180401                              None   0.93
# 185283                              None   2.79
# 187480                              None    1.7
# 193520                              None   0.99
# 198779                              None    1.4
# 198780                              None   None
# 203846  9b98b8c7a33c4b65b9aebfe6a799e6d9   None
# 222483  9b98b8c7a33c4b65b9aebfe6a799e6d9   None
# 222484                              None   0.27
# 235588                              None   1.02
# 237713                              None    2.7
# 247375  4d5c57ea9a6940dd891ad53e9dbe8da0   None
# 258696                              None   4.13
# 266174                              None   0.31
# 275001                              None   5.64
# 275002                              None   None
# 282196  4d5c57ea9a6940dd891ad53e9dbe8da0   None
# 282197                              None   6.18
# 293425                              None   1.78
# 295012                              None   0.41
# 298164                              None   0.42
# 300877                              None   0.73
# 302162                              None   4.96
# 303445                              None    0.9
