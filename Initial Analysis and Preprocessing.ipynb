# %% [markdown]
# # Exploratory Analysis for Starbucks Data and Preprocessing

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Initial Analysis and Preprocessing.ipynb',
#  'offers_transformed.csv',
#  'Original Datasources (Do Not Modify)',
#  'portfolio.csv',
#  'portfolio_transformed.csv',
#  'profile.csv',
#  'profile_transformed.csv',
#  'transactions_transformed',
#  'transcript.csv']

# %% [markdown]
# Please verify that you've unzipped the file archive & that portfolio.csv, profile.csv, and transcript.csv are all present in your current directory.

# %% [markdown]
# ## Loading data

# %%
import pandas as pd

# %%
port = pd.read_csv('portfolio.csv', index_col = 0) # index col = 0 since the index is unnamed in the csvs
prof = pd.read_csv('profile.csv', index_col = 0)
tran = pd.read_csv('transcript.csv', index_col = 0)

# %% [markdown]
# ## Examining and Preprocessing Data

# %% [markdown]
# ### Profile Data

# %%
prof.head()
# Out:
#   gender  age                                id  became_member_on    income
# 0    NaN  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1      F   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2    NaN  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3      F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4    NaN  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN

# %%
prof.isna().sum() # Looks like we are missing the same amount of gender / income.
# Out:
# gender              2175
# age                    0
# id                     0
# became_member_on       0
# income              2175
# dtype: int64

# %%
(prof['age'] == 118).value_counts()
# Out:
# False    14825
# True      2175
# Name: age, dtype: int64

# %%
print('Missing data makes up about {}% of total profile rows'.format(round(2175/(14825+2175), 3) * 100))
# Out:
# Missing data makes up about 12.8% of total profile rows

# %% [markdown]
# So, all of the missing values occur on the same rows - where one column is missing data, so are the others (gender, age, income). For now, lets just drop them.

# %%
prof.dropna(inplace = True)

# %%
prof.isna().any() # Verify there are no missing values in prof
# Out:
# gender              False
# age                 False
# id                  False
# became_member_on    False
# income              False
# dtype: bool

# %% [markdown]
# ### Transcript Data

# %%
tran.isna().sum() # No missing values for tran file!
# Out:
# person    0
# event     0
# value     0
# time      0
# dtype: int64

# %%
tran.head()
# Out:
#                              person           event  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received
# 1  a03223e636434f42ac4c3df47e8bac43  offer received
# 2  e2127556f4f64592b11af22de27a7932  offer received
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  offer received
# 4  68617ca6246f4fbc85e91a2a49552598  offer received
#
#                                               value  time
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0
# 2  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}     0
# 3  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}     0
# 4  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0

# %%
tran['event'].value_counts()
# Out:
# transaction        138953
# offer received      76277
# offer viewed        57725
# offer completed     33579
# Name: event, dtype: int64

# %% [markdown]
# ### Writing Functions for Parsing the "Value Column"
# The value column contains different information about value (offer id, reward, transaction amount) depending on what kind of "event" row it is - so we write a function to parse this information into their own columns and then iterate through the dataframe.

# %%
import ast

# %%
tran['offer_id'] = None
tran['amount'] = None
tran['reward'] = None


def parse_event_value():
    if i[1]['event'] == 'offer received':
        tran.at[i[0], 'offer_id'] = ast.literal_eval(i[1]['value'])['offer id']
    elif i[1]['event'] == 'offer viewed':
        tran.at[i[0], 'offer_id'] = ast.literal_eval(i[1]['value'])['offer id']
    elif i[1]['event'] == 'offer completed':
        tran.at[i[0], 'reward'] = ast.literal_eval(i[1]['value'])['reward']
        tran.at[i[0], 'offer_id'] = ast.literal_eval(i[1]['value'])['offer_id']
    elif i[1]['event'] == 'transaction':
        tran.at[i[0], 'amount'] = ast.literal_eval(i[1]['value'])['amount']

# %%
for i in tran.iterrows():
    parse_event_value()

# %% [markdown]
# ### Separation and Self-Joins
# We separate out the transcript dataframe by 'event' to make joins easier, then rename the columns of each column BEFORE the join for clarity.

# %%
transactions_only = tran[tran['event'] == 'transaction'].copy().drop(['value','offer_id', 'reward'], axis = 1)
completed_only = tran[tran['event'] == 'offer completed'].copy().drop(['value', 'amount'], axis = 1)
received_only = tran[tran['event'] == 'offer received'].copy().drop(['value', 'amount', 'reward'], axis = 1)
viewed_only = tran[tran['event'] == 'offer viewed'].copy().drop(['value', 'amount', 'reward'], axis = 1)

# %%
transactions_only.columns
# Out:
# Index(['person', 'event', 'time', 'amount'], dtype='object')

# %%
transactions_only = transactions_only.rename(columns = {'event':'transaction', 'time':'transaction time'})

# %%
completed_only.columns
# Out:
# Index(['person', 'event', 'time', 'offer_id', 'reward'], dtype='object')

# %%
completed_only = completed_only.rename(columns = {'event':'completed', 'time':'completed time'})

# %%
received_only.columns
# Out:
# Index(['person', 'event', 'time', 'offer_id'], dtype='object')

# %%
received_only = received_only.rename(columns = {'event': 'received', 'time':'received time'})

# %%
viewed_only.columns
# Out:
# Index(['person', 'event', 'time', 'offer_id'], dtype='object')

# %%
viewed_only = viewed_only.rename(columns = {'event': 'viewed', 'time':'viewed time'})

# %% [markdown]
# Now, we rejoin the transaction data frame together using left joins to create a dataframe with one row for each transaction, and information about whether or not it was related to an offer. This dataframe is interesting for analysis, but isn't as useful for our predictions.

# %%
tran_updated = pd.merge(transactions_only, completed_only, how = 'left', \
                        left_on = ['person', 'transaction time'], right_on = ['person', 'completed time'])

# %%
tran_updated = pd.merge(tran_updated, received_only, how = 'left', \
                        left_on = ['person', 'offer_id'], right_on = ['person', 'offer_id'])

# %%
tran_updated = pd.merge(tran_updated, viewed_only, how = 'left', \
                        left_on = ['person', 'offer_id'], right_on = ['person', 'offer_id'])

# %%
tran_updated
# Out:
#                                   person  transaction  transaction time  \
# 0       02c083884c7d45b39cc68e1314fec56c  transaction                 0
# 1       9fa9ae8f57894cc9a3b8a9bbe0fc1b2f  transaction                 0
# 2       54890f68699049c2a04d415abc25e717  transaction                 0
# 3       b2f1cd155b864803ad8334cdf13c4bd2  transaction                 0
# 4       fe97aa22dd3e48c8b143116a8403dd52  transaction                 0
# ...                                  ...          ...               ...
# 175728  b3a1272bc9904337b331bf348c3e8c17  transaction               714
# 175729  68213b08d99a4ae1b0dcb72aebd9aa35  transaction               714
# 175730  a00058cf10334a308c68e7631c529907  transaction               714
# 175731  76ddbd6576844afe811f1a3c0fbb5bec  transaction               714
# 175732  c02b10e8752c4d8e9b73f918558531f7  transaction               714
#
#        amount        completed  completed time  \
# 0        0.83              NaN             NaN
# 1       34.56  offer completed             0.0
# 2       13.23              NaN             NaN
# 3       19.51              NaN             NaN
# 4       18.97  offer completed             0.0
# ...       ...              ...             ...
# 175728   1.59              NaN             NaN
# 175729   9.53              NaN             NaN
# 175730   3.61              NaN             NaN
# 175731   3.53              NaN             NaN
# 175732   4.05              NaN             NaN
#
#                                 offer_id reward        received  \
# 0                                    NaN    NaN             NaN
# 1       2906b810c7d4411798c6938adc9daaa5      2  offer received
# 2                                    NaN    NaN             NaN
# 3                                    NaN    NaN             NaN
# 4       fafdcd668e3743c1bb461111dcafc2a4      2  offer received
# ...                                  ...    ...             ...
# 175728                               NaN    NaN             NaN
# 175729                               NaN    NaN             NaN
# 175730                               NaN    NaN             NaN
# 175731                               NaN    NaN             NaN
# 175732                               NaN    NaN             NaN
#
#         received time        viewed  viewed time
# 0                 NaN           NaN          NaN
# 1                 0.0  offer viewed          0.0
# 2                 NaN           NaN          NaN
# 3                 NaN           NaN          NaN
# 4                 0.0  offer viewed          6.0
# ...               ...           ...          ...
# 175728            NaN           NaN          NaN
# 175729            NaN           NaN          NaN
# 175730            NaN           NaN          NaN
# 175731            NaN           NaN          NaN
# 175732            NaN           NaN          NaN
#
# [175733 rows x 12 columns]

# %% [markdown]
# Now, having we rejoin the offer data  together using left joins to create a dataframe with one row for each unique offer for each person, and information about whether or not it was 'turned into' or 'converted' into a transaction. This dataframe will make up the basis of our training data once joined with other demographic / offer information.

# %%
offer_updated = pd.merge(received_only,viewed_only, how = 'left', \
                         left_on = ['person', 'offer_id'], right_on = ['person', 'offer_id'])

# %%
offer_updated = pd.merge(offer_updated, completed_only,  how = 'left', 
                         left_on = ['person', 'offer_id'], right_on = ['person', 'offer_id'])

# %%
offer_updated = pd.merge(offer_updated, transactions_only, how = 'left', \
                         left_on = ['person', 'completed time'], right_on = ['person', 'transaction time'])

# %%
offer_updated
# Out:
#                                   person        received  received time  \
# 0       78afa995795e4d85b5d9ceeca43f5fef  offer received              0
# 1       a03223e636434f42ac4c3df47e8bac43  offer received              0
# 2       a03223e636434f42ac4c3df47e8bac43  offer received              0
# 3       e2127556f4f64592b11af22de27a7932  offer received              0
# 4       8ec6ce2a7e7949b1bf142def7d0e0586  offer received              0
# ...                                  ...             ...            ...
# 115604  d087c473b4d247ccb0abfef59ba12b0e  offer received            576
# 115605  cb23b66c56f64b109d673d5e56574529  offer received            576
# 115606  6d5f3a774f3d4714ab0c092238f3a1d7  offer received            576
# 115607  9dc1421481194dcd9400aec7c9ae6366  offer received            576
# 115608  e4052622e5ba45a8b96b59aba68cf068  offer received            576
#
#                                 offer_id        viewed  viewed time  \
# 0       9b98b8c7a33c4b65b9aebfe6a799e6d9  offer viewed          6.0
# 1       0b1e1539f2cc45b7b9fa7c272da2e1d7  offer viewed          6.0
# 2       0b1e1539f2cc45b7b9fa7c272da2e1d7  offer viewed        624.0
# 3       2906b810c7d4411798c6938adc9daaa5  offer viewed         18.0
# 4       fafdcd668e3743c1bb461111dcafc2a4  offer viewed         12.0
# ...                                  ...           ...          ...
# 115604  ae264e3637204a6fb9bb56bc8210ddfd  offer viewed        672.0
# 115605  2906b810c7d4411798c6938adc9daaa5           NaN          NaN
# 115606  2298d6c36e964ae4a3e7e9706d1fb8c2  offer viewed        588.0
# 115607  ae264e3637204a6fb9bb56bc8210ddfd  offer viewed        624.0
# 115608  3f207df678b143eea3cee63160fa8bed           NaN          NaN
#
#               completed  completed time reward  transaction  transaction time  \
# 0       offer completed           132.0      5  transaction             132.0
# 1                   NaN             NaN    NaN          NaN               NaN
# 2                   NaN             NaN    NaN          NaN               NaN
# 3                   NaN             NaN    NaN          NaN               NaN
# 4                   NaN             NaN    NaN          NaN               NaN
# ...                 ...             ...    ...          ...               ...
# 115604  offer completed           636.0     10  transaction             636.0
# 115605  offer completed           156.0      2  transaction             156.0
# 115606              NaN             NaN    NaN          NaN               NaN
# 115607  offer completed           594.0     10  transaction             594.0
# 115608              NaN             NaN    NaN          NaN               NaN
#
#        amount
# 0       19.89
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 115604  20.78
# 115605  21.62
# 115606    NaN
# 115607  12.57
# 115608    NaN
#
# [115609 rows x 12 columns]

# %% [markdown]
# It's rather ugly to have a value for "viewed" if the offer was viewed and NaN if it isn't, so we write a quick looping function to convert these columns to 0/1 (where 1 is TRUE and 0 is FALSE)

# %%
import numpy as np

# %%
transform_list = ['received', 'viewed', 'completed', 'transaction']

# %%
def encode_cols(df):
    for i in transform_list:
        try:
            df[i] = np.where(df[i].isnull(), 0, 1)
        except:
            pass

# %%
encode_cols(offer_updated)

# %%
offer_updated
# Out:
#                                   person  received  received time  \
# 0       78afa995795e4d85b5d9ceeca43f5fef         1              0
# 1       a03223e636434f42ac4c3df47e8bac43         1              0
# 2       a03223e636434f42ac4c3df47e8bac43         1              0
# 3       e2127556f4f64592b11af22de27a7932         1              0
# 4       8ec6ce2a7e7949b1bf142def7d0e0586         1              0
# ...                                  ...       ...            ...
# 115604  d087c473b4d247ccb0abfef59ba12b0e         1            576
# 115605  cb23b66c56f64b109d673d5e56574529         1            576
# 115606  6d5f3a774f3d4714ab0c092238f3a1d7         1            576
# 115607  9dc1421481194dcd9400aec7c9ae6366         1            576
# 115608  e4052622e5ba45a8b96b59aba68cf068         1            576
#
#                                 offer_id  viewed  viewed time  completed  \
# 0       9b98b8c7a33c4b65b9aebfe6a799e6d9       1          6.0          1
# 1       0b1e1539f2cc45b7b9fa7c272da2e1d7       1          6.0          0
# 2       0b1e1539f2cc45b7b9fa7c272da2e1d7       1        624.0          0
# 3       2906b810c7d4411798c6938adc9daaa5       1         18.0          0
# 4       fafdcd668e3743c1bb461111dcafc2a4       1         12.0          0
# ...                                  ...     ...          ...        ...
# 115604  ae264e3637204a6fb9bb56bc8210ddfd       1        672.0          1
# 115605  2906b810c7d4411798c6938adc9daaa5       0          NaN          1
# 115606  2298d6c36e964ae4a3e7e9706d1fb8c2       1        588.0          0
# 115607  ae264e3637204a6fb9bb56bc8210ddfd       1        624.0          1
# 115608  3f207df678b143eea3cee63160fa8bed       0          NaN          0
#
#         completed time reward  transaction  transaction time amount
# 0                132.0      5            1             132.0  19.89
# 1                  NaN    NaN            0               NaN    NaN
# 2                  NaN    NaN            0               NaN    NaN
# 3                  NaN    NaN            0               NaN    NaN
# 4                  NaN    NaN            0               NaN    NaN
# ...                ...    ...          ...               ...    ...
# 115604           636.0     10            1             636.0  20.78
# 115605           156.0      2            1             156.0  21.62
# 115606             NaN    NaN            0               NaN    NaN
# 115607           594.0     10            1             594.0  12.57
# 115608             NaN    NaN            0               NaN    NaN
#
# [115609 rows x 12 columns]

# %%
encode_cols(tran_updated)

# %%
tran_updated
# Out:
#                                   person  transaction  transaction time  \
# 0       02c083884c7d45b39cc68e1314fec56c            1                 0
# 1       9fa9ae8f57894cc9a3b8a9bbe0fc1b2f            1                 0
# 2       54890f68699049c2a04d415abc25e717            1                 0
# 3       b2f1cd155b864803ad8334cdf13c4bd2            1                 0
# 4       fe97aa22dd3e48c8b143116a8403dd52            1                 0
# ...                                  ...          ...               ...
# 175728  b3a1272bc9904337b331bf348c3e8c17            1               714
# 175729  68213b08d99a4ae1b0dcb72aebd9aa35            1               714
# 175730  a00058cf10334a308c68e7631c529907            1               714
# 175731  76ddbd6576844afe811f1a3c0fbb5bec            1               714
# 175732  c02b10e8752c4d8e9b73f918558531f7            1               714
#
#        amount  completed  completed time                          offer_id  \
# 0        0.83          0             NaN                               NaN
# 1       34.56          1             0.0  2906b810c7d4411798c6938adc9daaa5
# 2       13.23          0             NaN                               NaN
# 3       19.51          0             NaN                               NaN
# 4       18.97          1             0.0  fafdcd668e3743c1bb461111dcafc2a4
# ...       ...        ...             ...                               ...
# 175728   1.59          0             NaN                               NaN
# 175729   9.53          0             NaN                               NaN
# 175730   3.61          0             NaN                               NaN
# 175731   3.53          0             NaN                               NaN
# 175732   4.05          0             NaN                               NaN
#
#        reward  received  received time  viewed  viewed time
# 0         NaN         0            NaN       0          NaN
# 1           2         1            0.0       1          0.0
# 2         NaN         0            NaN       0          NaN
# 3         NaN         0            NaN       0          NaN
# 4           2         1            0.0       1          6.0
# ...       ...       ...            ...     ...          ...
# 175728    NaN         0            NaN       0          NaN
# 175729    NaN         0            NaN       0          NaN
# 175730    NaN         0            NaN       0          NaN
# 175731    NaN         0            NaN       0          NaN
# 175732    NaN         0            NaN       0          NaN
#
# [175733 rows x 12 columns]

# %% [markdown]
# At this point, tran_updated and offer_updated are mostly complete, so we move onto the portfolio.csv.

# %% [markdown]
# ## Portfolio Data / Offer Information

# %%
port
# Out:
#    reward                              channels  difficulty  duration  \
# 0      10         ['email', 'mobile', 'social']          10         7
# 1      10  ['web', 'email', 'mobile', 'social']          10         5
# 2       0            ['web', 'email', 'mobile']           0         4
# 3       5            ['web', 'email', 'mobile']           5         7
# 4       5                      ['web', 'email']          20        10
# 5       3  ['web', 'email', 'mobile', 'social']           7         7
# 6       2  ['web', 'email', 'mobile', 'social']          10        10
# 7       0         ['email', 'mobile', 'social']           0         3
# 8       5  ['web', 'email', 'mobile', 'social']           5         5
# 9       2            ['web', 'email', 'mobile']          10         7
#
#       offer_type                                id
# 0           bogo  ae264e3637204a6fb9bb56bc8210ddfd
# 1           bogo  4d5c57ea9a6940dd891ad53e9dbe8da0
# 2  informational  3f207df678b143eea3cee63160fa8bed
# 3           bogo  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 4       discount  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 5       discount  2298d6c36e964ae4a3e7e9706d1fb8c2
# 6       discount  fafdcd668e3743c1bb461111dcafc2a4
# 7  informational  5a8bc65990b245e5a138643cd4eb9837
# 8           bogo  f19421c1d4aa40978ebb69ca19b0e20d
# 9       discount  2906b810c7d4411798c6938adc9daaa5

# %%
port['email'] = 0
port['social'] = 0
port['mobile'] = 0
port['web'] = 0

def parse_channels_value():
    channels = ast.literal_eval(i[1]['channels'])
    if 'email' in channels:
        port.at[i[0], 'email'] = 1
    else:
        port.at[i[0], 'email'] = 0 
    if 'mobile' in channels:
        port.at[i[0], 'mobile'] = 1
    else:
        port.at[i[0], 'mobile'] = 0
    if 'web' in channels:
        port.at[i[0], 'web'] = 1
    else:
        port.at[i[0], 'web'] = 0
    if 'social' in channels:
        port.at[i[0], 'social'] = 1
    else:
        port.at[i[0], 'social'] = 0

# %%
for i in port.iterrows():
    parse_channels_value()

# %%
port.drop(['channels'], inplace = True, axis = 1)

# %%
port
# Out:
#    reward  difficulty  duration     offer_type  \
# 0      10          10         7           bogo
# 1      10          10         5           bogo
# 2       0           0         4  informational
# 3       5           5         7           bogo
# 4       5          20        10       discount
# 5       3           7         7       discount
# 6       2          10        10       discount
# 7       0           0         3  informational
# 8       5           5         5           bogo
# 9       2          10         7       discount
#
#                                  id  email  social  mobile  web
# 0  ae264e3637204a6fb9bb56bc8210ddfd      1       1       1    0
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0      1       1       1    1
# 2  3f207df678b143eea3cee63160fa8bed      1       0       1    1
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9      1       0       1    1
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7      1       0       0    1
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2      1       1       1    1
# 6  fafdcd668e3743c1bb461111dcafc2a4      1       1       1    1
# 7  5a8bc65990b245e5a138643cd4eb9837      1       1       1    0
# 8  f19421c1d4aa40978ebb69ca19b0e20d      1       1       1    1
# 9  2906b810c7d4411798c6938adc9daaa5      1       0       1    1

# %% [markdown]
# # Exporting Transformed Code

# %%
prof.to_csv('profile_transformed.csv')
port.to_csv('portfolio_transformed.csv')
offer_updated.to_csv('offers_transformed.csv')
tran_updated.to_csv('transactions_transformed.csv')
